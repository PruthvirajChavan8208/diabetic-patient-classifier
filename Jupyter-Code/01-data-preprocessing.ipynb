# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
ds = pd.read_csv("diabetic.csv")

# %%
ds.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
#Count of columns
len(ds.columns)
#8 - independent and 1 dependent
# Out:
# 9

# %%
#Glucose - 0 is not allowed. values must be above 69
#BloodPressure - values must be above 39
#SkinThickness - must be above 0
#Insulin - must be above 0
#BMI - 0 not allowed
# Out:
# 768

# %%
ds["Glucose"] = ds["Glucose"].apply(checkGlucoseValue)

# %%
def checkGlucoseValue(value):
    if value < 70:
        return np.nan
    else:
        return value

# %%
gMean = ds["Glucose"].mean()
ds["Glucose"] = ds["Glucose"].fillna(gMean)

# %%
def checkBloodPressureValue(value):
    if value < 39:
        return np.nan
    else:
        return value

# %%
ds["BloodPressure"] = ds["BloodPressure"].apply(checkBloodPressureValue)

# %%
bpMean = ds["BloodPressure"].mean()
ds["BloodPressure"] = ds["BloodPressure"].fillna(bpMean)

# %%
ds["BloodPressure"].unique()
# Out:
# array([ 72.       ,  66.       ,  64.       ,  40.       ,  74.       ,
#         50.       ,  72.6351166,  70.       ,  96.       ,  92.       ,
#         80.       ,  60.       ,  84.       ,  88.       ,  90.       ,
#         94.       ,  76.       ,  82.       ,  75.       ,  58.       ,
#         78.       ,  68.       , 110.       ,  56.       ,  62.       ,
#         85.       ,  86.       ,  48.       ,  44.       ,  65.       ,
#        108.       ,  55.       , 122.       ,  54.       ,  52.       ,
#         98.       , 104.       ,  95.       ,  46.       , 102.       ,
#        100.       ,  61.       , 106.       , 114.       ])

# %%
ds['SkinThickness'] = ds['SkinThickness'].replace(0, np.nan)
stMean = ds['SkinThickness'].mean()
ds['SkinThickness'] = ds['SkinThickness'].fillna(stMean)

# %%
ds['Insulin'] = ds['Insulin'].replace(0, np.nan)
stInsulin = ds['Insulin'].mean()
ds['Insulin'] = ds['Insulin'].fillna(stInsulin)

# %%
ds['BMI'] = ds['BMI'].replace(0, np.nan)
stBMI = ds['BMI'].mean()
ds['BMI'] = ds['BMI'].fillna(stBMI)

# %%
ds.to_csv("cleaned_data.csv")
